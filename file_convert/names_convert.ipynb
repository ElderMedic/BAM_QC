# %%
import os
import re
import sys

# %%
def read_name_dmp(dmpfile):
    dict1={}
    if dmpfile.endswith('.dmp'):
        with open(dmpfile) as rd:
            for line in rd:
                text=line.rstrip('\t|\n').split('\t|\t')
                if int(text[0]) in dict1.keys():
                    dict1[int(text[0])]=dict1[int(text[0])]+' | '+text[1]+' * '+text[3]
                else:
                    dict1[int(text[0])]=text[1]+' * '+text[3]
        return dict1
    else:
        raise ValueError('invalid input file!')
            


def out_file(dic,out_dir):
    if not os.path.exists(out_dir):
        for i in dic.keys():
            with open(out_dir,'a+') as w:
                result=str(i)+' | '+dic[i]+' | \n'
            
                w.write(result)
    else:
        raise ValueError('pls delete existing file!')
            
    


if __name__=='__main__':
    dict2=read_name_dmp('/home/kechanglin/data/data_conversion/names.dmp')
    out_file(dict2,'/home/kechanglin/data/data_conversion/name_result')

# %%
# Out:
# (1, 'all * synonym | root * scientific name')
# (2, 'Bacteria * scientific name | Monera * in-part | Procaryotae * in-part | Prokaryota * in-part | Prokaryotae * in-part | bacteria * blast name | eubacteria * genbank common name | prokaryote * in-part | prokaryotes * in-part')
# (6, 'Azorhizobium * scientific name | Azorhizobium Dreyfus et al. 1988 emend. Lang et al. 2013 * authority')
# (7, 'Azorhizobium caulinodans * scientific name | Azorhizobium caulinodans Dreyfus et al. 1988 * authority | Azotirhizobium caulinodans * equivalent name')
# (9, 'Acyrthosiphon pisum symbiont P * includes | Buchnera aphidicola * scientific name | Buchnera aphidicola Munson et al. 1991 * authority | primary endosymbiont of Schizaphis graminum * includes')
# (10, '"Cellvibrio" Winogradsky 1929 * authority | Cellvibrio * scientific name | Cellvibrio (ex Winogradsky 1929) Blackall et al. 1986 emend. Humphry et al. 2003 * authority | Cellvibrio (ex Winogradsky 1929) Blackall et al. 1986 emend. Suarez et al. 2014 * authority')
# (11, '"Cellulomonas gilvus" (Hulcher and King 1958) Christopherson et al. 2013 * authority | "Cellvibrio gilvus" Hulcher and King 1958 * authority | Cellulomonas gilvus * scientific name | Cellvibrio gilvus * synonym')
# (13, 'Dictyoglomus * scientific name | Dictyoglomus Saiki et al. 1985 * authority')
# (14, 'Dictyoglomus thermophilum * scientific name | Dictyoglomus thermophilum Saiki et al. 1985 * authority')
# (16, 'Methyliphilus * equivalent name | Methylophilus * scientific name | Methylophilus Jenkins et al. 1987 * authority')
# (17, 'Methyliphilus methylitrophus * equivalent name | Methyliphilus methylotrophus * equivalent name | Methylophilus methylitrophus * equivalent name | Methylophilus methylotrophus * scientific name | Methylophilus methylotrophus Jenkins et al. 1987 * authority | Methylophilus sp. CBMB147 * includes | Methylotrophus methylophilus * synonym')
# (18, 'Pelobacter * scientific name | Pelobacter Schink and Pfennig 1983 * authority')
# (19, 'Pelobacter carbinolicus * scientific name | Pelobacter carbinolicus Schink 1984 * authority')
# (20, 'Phenylobacterium * scientific name | Phenylobacterium Lingens et al. 1985 emend. Abraham et al. 2008 * authority | Phenylobacterium Lingens et al. 1985 emend. Kanso and Patel 2004 * authority | Phenylobacterium Lingens et al. 1985 emend. Oh and Roh 2012 * authority | Phenylobacterium Lingens et al. 1985 emend. Tiago et al. 2005 * authority')
# (21, 'Phenylobacterium immobile * scientific name | Phenylobacterium immobile Lingens et al. 1985 * authority')
# (22, 'Shewanella * scientific name | Shewanella MacDonell and Colwell 1986 * authority')
# (23, 'Alteromonas colwelliana * synonym | Alteromonas colwelliana Weiner et al. 1988 * authority | Shewanella affinis * synonym | Shewanella affinis Ivanova et al. 2004 * authority | Shewanella colwelliana * scientific name | Shewanella colwelliana (Weiner et al. 1988) Coyne et al. 1990 * authority')
# (24, '"Pseudomonas putrefaciens" (Derby and Hammer) Long and Hammer 1941 * authority | Alteromonas putrefaciens * synonym | Alteromonas putrefaciens (ex Derby and Hammer) Lee et al. 1981 * authority | Pseudomonas putrefaciens * synonym | Shewanella putrefaciens * scientific name | Shewanella putrefaciens (Lee et al. 1981) MacDonell and Colwell 1986 * authority')
# (25, 'Alteromonas hanedai * synonym | Alteromonas hanedai Jensen et al. 1981 * authority | Shewanella hanedai * scientific name | Shewanella hanedai (Jensen et al. 1981) MacDonell and Colwell 1986 * authority')
# (27, 'halophilic eubacterium (NRCC 41227) * synonym | halophilic eubacterium NRCC 41227 * scientific name | halophilic eubacterium NRCC41227 * synonym')
# (28, 'halophilic eubacterium * scientific name')
# (29, 'Myxobacteria * synonym | Myxococcales * scientific name | Myxococcales Tchan et al. 1948 * authority | The Myxobacteria * synonym | fruiting gliding bacteria * genbank common name')
# (31, 'Myxococcaceae * scientific name | Myxococcaceae Jahn et al. 1924 (Approved Lists 1980) emend. Lang et al. 2015 * authority')
# (32, 'Myxococcus * scientific name | Myxococcus Thaxter 1892 emend. Lang and Stackebrandt 2009 * authority')
# (33, '"Micrococcus fulvus" Cohn 1875 * authority | Micrococcus fulvus * synonym | Myxococcus fulvus * scientific name | Myxococcus fulvus (Cohn 1875) Jahn 1911 * authority')
# (34, 'Myxococcus xanthus * scientific name | Myxococcus xanthus Beebe 1941 * authority | Myxococcus xanthus retron Mx162 * includes | Myxococcus xanthus retron Mx65 * includes')
# (35, '"Chondrococcus macrosporus" Krzemieniewska and Krzemieniewski 1926 * authority | Chondrococcus macrosporus * synonym | Corallococcus macrosporus * synonym | Corallococcus macrosporus Reichenbach 2007 * authority | Myxococcus macrosporus * scientific name | Myxococcus macrosporus (Krzemieniewska and Krzemieniewski 1926) Zahler and McCurdy 1974 (Approved Lists 1980) * authority')
# (38, '"Angiococcus disciformis" (Thaxter 1904) Jahn 1924 * authority | "Cystobacter disciformis" (Thaxter 1904) Brockman and McCurdy 1989 * authority | Angiococcus disciformis * synonym | Angiococcus disciformis (Thaxter 1904) Hook et al. 1980 * authority | Archangium disciforme * scientific name | Archangium disciforme (Thaxter 1904) Lang et al. 2015 * authority | Cystobacter disciformis * synonym | Myxococcus disciformis * synonym | Myxococcus disciformis Thaxter 1904 (Approved Lists 1980) * authority')
# (39, 'Archangiaceae * scientific name | Archangiaceae Jahn et al. 1924 (Approved Lists 1980) emend. Lang et al. 2015 * authority | Cystobacteraceae * synonym | Cystobacteraceae McCurdy 1970 (Approved Lists 1980) emend. Awal et al. 2017 * authority')
# (40, 'Stigmatella * scientific name | Stigmatella Berkeley and Curtis 1875 * authority')
# (41, '"Chondromyces aurantiacus" (Berkeley and Curtis) Thaxter 1892 * authority | Chondromyces aurantiacus * synonym | Stigmatella aurantiaca * scientific name | Stigmatella aurantiaca Berkeley and Curtis 1875 * authority')
# (42, 'Cystobacter * scientific name | Cystobacter Schroeter 1886 * authority')
# (43, '"Polyangium fuscum" (Schroeter 1886) Thaxter 1904 * authority | Cystobacter fuscus * scientific name | Cystobacter fuscus Schroeter 1886 * authority | Polyangium fuscum * synonym')
# (44, 'Melittangium * scientific name | Melittangium Jahn 1924 * authority')
# (45, '"Chondromyces gracilipes" Thaxter 1897 * authority | "Chondromyces lichenicolus" Thaxter 1892 * authority | "Chondromyces minor" Krzemieniewska and Krzemieniewski 1930 * authority | "Podangium gracilipes" (Thaxter 1897) Jahn 1924 * authority | "Podangium lichenicolum" (Thaxter 1892) Jahn 1924 * authority | Chondromyces gracilipes * synonym | Chondromyces lichenicolus * synonym | Chondromyces minor * synonym | Melittangium lichenicola * scientific name | Melittangium lichenicola (Thaxter 1892) McCurdy 1971 * authority | Podangium gracilipes * synonym | Podangium lichenicolum * synonym')
# (47, '"Angiococcus" Jahn 1924 * authority | Angiococcus * synonym | Angiococcus (ex Jahn 1924) Hook et al. 1980 emend. Awal et al. 2017 * authority | Archangium * scientific name | Archangium Jahn 1924 (Approved Lists 1980) Lang et al. 2015 * authority | Archangium Jahn 1924 (Approved Lists 1980) emend. Awal et al. 2017 * authority')
# (48, '"Chondrococcus cerebriformis" (Kofler) Jahn 1924 * authority | "Chondromyces serpens" Quehl 1906 * authority | "Myxococcus cerebriformis" Kofler 1913 * authority | Archangium gephyra * scientific name | Archangium gephyra Jahn 1924 (Approved Lists 1980) emend. Lang et al. 2015 * authority | Chondrococcus cerebriformis * synonym | Chondromyces serpens * synonym | Myxococcus cerebriformis * synonym')
# (49, '"Sorangiaceae" Jahn 1924 * authority | Polyangiaceae * scientific name | Polyangiaceae Jahn 1924 * authority | Sorangiaceae * includes')
# (50, '"Myxobotrys" Zukal 1896 * authority | "Polycephalum" Kalchbrenner and Cooke 1880 * authority | Chondromyces * scientific name | Chondromyces Berkeley and Curtis 1874 * authority | Myxobotrys * synonym | Polycephalum * synonym')
# (51, 'Chondromyces apiculatus * scientific name | Chondromyces apiculatus Thaxter 1897 * authority')
# (52, '"Myxobotrys variabilis" Zukal 1896 * authority | Chondromyces crocatus * scientific name | Chondromyces crocatus Berkeley and Curtis 1874 * authority | Myxobotrys variabilis * synonym')
# (53, 'Nannocystis * scientific name | Nannocystis Reichenbach 1970 * authority')
# (54, 'Nannocystis exedens * scientific name | Nannocystis exedens Reichenbach 1970 * authority')
# (55, 'Polyangium * scientific name | Polyangium Link 1809 * authority')
# (56, '"Polyangium compositum" Thaxter 1904 * authority | "Sorangium cellulosum" (Imshenetski and Solntseva 1936) Imshenetski and Solntseva 1937 * authority | "Sorangium compositum" Jahn 1924 * authority | "Sorangium compositum" Krzemieniewska and Krzemieniewski 1937 * authority | "Sorangium nigrescens" Krzemieniewska and Krzemieniewski 1937 * authority | "Sorangium nigrum" Krzemieniewska and Krzemieniewski 1937 * authority | Polyangium cellulosum * synonym | Polyangium cellulosum (ex Imshenetski and Solntseva 1936) Brockman 1989 * authority | Polyangium compositum * synonym | Sorangium cellulosum * scientific name | Sorangium cellulosum (Brockman 1989) Reichenbach 2007 * authority | Sorangium compositum * synonym | Sorangium nigrescens * synonym | Sorangium nigrum * synonym')
# (57, 'Polyangium sp. * scientific name')
# (59, 'Vitreoscilla * scientific name | Vitreoscilla Pringsheim 1949 * authority')
# (60, 'Vitreoscilla sp. * scientific name')
# (61, 'Vitreoscilla stercoraria * scientific name | Vitreoscilla stercoraria Pringsheim 1951 (Approved Lists 1980) emend. Strohl et al. 1986 * authority')
# (62, 'Vitreoscilla beggiatoides * scientific name | Vitreoscilla beggiatoides Pringsheim 1949 (Approved Lists 1980) emend. Strohl et al. 1986 * authority')
# (63, '"Vitreoscilla filiformis" Pringsheim 1951 * authority | Vitreoscilla filiformis * scientific name | Vitreoscilla filiformis (ex Pringsheim 1951) Strohl et al. 1986 * authority')
# (64, 'Herpetosiphon * scientific name | Herpetosiphon Holt and Lewin 1968 * authority')
# (65, 'Herpetosiphon aurantiacus * scientific name | Herpetosiphon aurantiacus Holt and Lewin 1968 * authority')
# (68, 'Lysobacter * scientific name | Lysobacter Christensen and Cook 1978 (Approved Lists 1980) emend. Park et al. 2008 * authority')
# (69, 'Lysobacter enzymogenes * scientific name | Lysobacter enzymogenes Christensen and Cook 1978 (Approved Lists 1980) emend. Lin et al. 2016 * authority | Lysobacter enzymogenes subsp. enzymogenes * includes | Lysobacter enzymogenes subsp. enzymogenes Christensen and Cook 1978 * authority')
# (71, 'Simonsiella * scientific name | Simonsiella Schmid 1922 * authority')
# (72, '"Caryophanon muelleri" (Schmid 1922) Peshkoff 1948 * authority | Caryophanon muelleri * synonym | Scheibenbakterien * common name | Scheibenbakterien Muller 1911 * common name | Simonsiella muelleri * scientific name | Simonsiella muelleri Schmid 1922 * authority')
# (75, 'Caulobacter * scientific name | Caulobacter Henrici and Johnson 1935 (Approved Lists 1980) emend. Abraham et al. 1999 * authority')
# (78, 'Caulobacter sp. * scientific name')
# (81, 'Hyphomicrobium * scientific name | Hyphomicrobium Stutzer and Hartleb 1898 * authority | Hyphomicrobium Stutzer and Hartleb 1899 (sic) * authority')
# (82, 'Hyphomicrobium sp. * scientific name')
# (83, 'Hyphomicrobium vulgare * scientific name | Hyphomicrobium vulgare Stutzer and Hartleb 1898 * authority | Hyphomicrobium vulgare Stutzer and Hartleb 1899 (sic) * authority')
# (84, 'Hyphomicrobium methylovorum * scientific name | Hyphomicrobium methylovorum Izumi et al. 1983 * authority')
# (85, 'Hyphomonas * scientific name | Hyphomonas (ex Pongratz 1957) Moore et al. 1984 emend. Li et al. 2014 * authority | Hyphomonas (ex Pongratz 1957) Moore et al. 1984 emend. Weiner et al. 2000 * authority')
# (86, 'Hyphomonas jannaschiana * scientific name | Hyphomonas jannaschiana Weiner et al. 1985 * authority')
# (87, 'Hyphomonas sp. * scientific name')
# (88, '"Chlamydothrix" Migula 1900 * authority | "Detoniella" Trevisan in de Toni and Trevisan 1889 * authority | Chlamydothrix * synonym | Detoniella * synonym | Leptothrix * scientific name | Leptothrix Kutzing 1843 * authority')
# (89, '"Leptothrix crassa" Cholodny 1924 * authority | "Leptothrix discophora" (Schwers 1912) Dorff 1934 * authority | "Megalothrix discophora" Schwers 1912 * authority | Leptothrix crassa * synonym | Leptothrix discophora * scientific name | Leptothrix discophora (ex Schwers 1912) Spring et al. 1997 * authority | Megalothrix discophora * synonym')
# (93, 'Stella * scientific name | Stella Vasilyeva 1985 * authority')
# (94, 'Stella humosa * scientific name | Stella humosa Vasilyeva 1985 * authority')
# (96, 'Gallionella * scientific name | Gallionella Ehrenberg 1838 * authority')
# (97, '"Chlamydothrix ferruginea" (Ehrenberg 1838) Migula 1900 * authority | "Spirillum ferrugineum" (Ehrenberg 1838) de Toni and Trevisan 1889 * authority | "Spirophyllum ferrugineum" (Ehrenberg 1838) Ellis 1907 * authority | Chlamydothrix ferruginea * synonym | Gallionella ferruginea * scientific name | Gallionella ferruginea Ehrenberg 1838 * authority | Spirillum ferrugineum * synonym | Spirophyllum ferrugineum * synonym')
# (99, '"Renobacter" Nikitin 1971 * authority | Ancylobacter * scientific name | Ancylobacter Raj 1983 * authority | Microcyclus * synonym | Microcyclus Orskov 1928 (Approved Lists 1980) * authority | Renobacter * synonym')
# (100, 'Ancylobacter aquaticus * scientific name | Ancylobacter aquaticus (Orskov 1928) Raj 1983 * authority | Microcyclus aquaticus * synonym | Microcyclus aquaticus Orskov 1928 (Approved Lists 1980) * authority')
# (101, 'Flectobacillus * scientific name | Flectobacillus Larkin et al. 1977 (Approved Lists 1980) emend. Raj and Maloy 1990 * authority | Flectobacillus Larkin et al. 1977 (Approved Lists 1980) emend. Ramaprasad et al. 2015 * authority')
# (102, 'Flectobacillus glomeratus * synonym | Flectobacillus glomeratus McGuire et al. 1988 * authority | Polaribacter glomeratus * scientific name | Polaribacter glomeratus (McGuire et al. 1988) Gosink et al. 1998 * authority')
# (103, '"Microcyclus major" Gromov 1963 * authority | Flectobacillus major * scientific name | Flectobacillus major (Gromov 1963) Larkin et al. 1977 (Approved Lists 1980) emend. Hahnke et al. 2016 * authority | Microcyclus major * synonym')
# (104, '"Microcyclus marinus" Raj 1976 * authority | Cyclobacterium marinum * scientific name | Cyclobacterium marinum corrig. (Raj 1976) Raj and Maloy 1990 emend. Hahnke et al. 2016 * authority | Flectobacillus marinus * synonym | Flectobacillus marinus (Raj 1976) Borrall and Larkin 1978 (Approved Lists 1980) * authority | Microcyclus marinus * synonym')
# (105, 'Runella * scientific name | Runella Larkin and Williams 1978 * authority')
# (106, 'Runella slithyformis * scientific name | Runella slithyformis Larkin and Williams 1978 (Approved Lists 1980) emend. Hahnke et al. 2016 * authority')
# (107, 'Spirosoma * scientific name | Spirosoma Migula 1894 (Approved Lists 1980) emend. Ahn et al. 2014 * authority | Spirosoma Migula 1894 (Approved Lists 1980) emend. Finster et al. 2009 * authority')
# (108, 'Spirosoma linguale * scientific name | Spirosoma linguale Migula 1894 (Approved Lists 1980) emend. Hahnke et al. 2016 * authority')
# (109, 'Blastobacter * scientific name | Blastobacter Zavarzin 1961 (Approved Lists 1980) emend. Sly 1985 * authority')
# (110, '"Blastobacter viscosus" Loginova and Trotensko 1979 * authority | "Blastobacter viscosus" Loginova and Trotsenok 1979 * authority | Blastobacter viscosus * synonym | Blastobacter viscosus 7d * includes | Xanthobacter viscosus * scientific name | Xanthobacter viscosus Doronina and Trotsenko 2003 * authority')
# (112, 'Planctomycetales * scientific name | Planctomycetales Schlesner and Stackebrandt 1987 * authority | Planctomycetales Schlesner and Stackebrandt 1987 emend. Scheuner et al. 2014 * authority | Planctomycetales Schlesner and Stackebrandt 1987 emend. Ward 2011 * authority | planctomycetes * blast name')
# (113, 'Gemmata * scientific name | Gemmata Franzmann and Skerman 1985 emend. Scheuner et al. 2014 * authority')
# (114, 'Gemmata obscuriglobus * scientific name | Gemmata obscuriglobus Franzmann and Skerman 1985 emend. Scheuner et al. 2014 * authority')
# (117, 'Pirellula sp. * scientific name')
# (118, '"Acinothrix" Novacek 1938 * authority | "Blastocaulis" Henrici and Johnson 1935 * authority | Acinothrix * synonym | Blastocaulis * synonym | Planctomyces * scientific name | Planctomyces Gimesi 1924 * authority')
# (119, 'Planctomyces brasiliensis * synonym | Planctomyces brasiliensis Schlesner 1990 * authority | Rubinisphaera brasiliensis * scientific name | Rubinisphaera brasiliensis (Schlesner 1990) Scheuner et al. 2015 * authority')
# (120, '"Planctopirus limnophilus" (Hirsch and Muller 1986) Scheuner et al. 2014 * authority | Planctomyces limnophilus * synonym | Planctomyces limnophilus Hirsch and Muller 1986 * authority | Planctopirus limnophila * scientific name | Planctopirus limnophila corrig. (Hirsch and Muller 1986) Scheuner et al. 2015 * authority | Planctopirus limnophilus * synonym')
# (122, '"Planctomyces maris" Bauld and Staley 1976 * authority | Gimesia maris * scientific name | Gimesia maris (Bauld and Staley 1980) Scheuner et al. 2015 * authority | Planctomyces maris * synonym | Planctomyces maris (ex Bauld and Staley 1976) Bauld and Staley 1980 * authority')
# (123, 'Pirellula * scientific name | Pirellula Schlesner and Hirsch 1987 emend. Schlesner et al. 2004 * authority')
# (124, 'Blastopirellula marina * scientific name | Blastopirellula marina (Schlesner and Hirsch 1987) Schlesner et al. 2004 emend. Hahnke et al. 2016 * authority | Pirellula marina * synonym | Pirellula marina (Schlesner 1987) Schlesner and Hirsch 1987 * authority')
# (125, 'Pasteuria ramosa ATCC 27377 * includes | Pirellula staleyi * scientific name | Pirellula staleyi Schlesner and Hirsch 1987 emend. Hahnke et al. 2016 * authority')
# (126, 'Planctomycetaceae * scientific name | Planctomycetaceae Schlesner and Stackebrandt 1987 * authority | Planctomycetaceae Schlesner and Stackebrandt 1987 emend. Scheuner et al. 2014 * authority | Planctomycetaceae Schlesner and Stackebrandt 1987 emend. Ward 2011 * authority')
# (127, 'Isosphaera * scientific name | Isosphaera Giovannoni et al. 1995 * authority')
# (128, '"Isocystis pallida" Woronichin 1927 (as cyanobacterium) * authority | "Torulopsidosira pallida" (Woronichin 1927) Geitler 1963 (as a yeast) * authority | Isocystis pallida * synonym | Isosphaera pallida * scientific name | Isosphaera pallida (ex Woronichin 1927) Giovannoni et al. 1995 * authority | Torulopsidosira pallida * synonym')
# (131, '"Tuberoidobacter" Nikitin 1970 * authority | Tuberoidobacter * scientific name')
# (132, "'Tuberoidobacter mutans' * synonym | Tuberoidobacter mutans * scientific name")
# (133, 'Methylocystis * scientific name | Methylocystis (ex Whittenbury et al. 1970) Bowman et al. 1993 emend. Belova et al. 2013 * authority | Methylocystis (ex Whittenbury et al. 1970) Bowman et al. 1993 emend. Dedysh et al. 2007 * authority')
# (134, 'Methylocystis parvus * scientific name | Methylocystis parvus Bowman et al. 1993 * authority')
# (136, 'Spirochaetales * scientific name | Spirochaetales Buchanan 1917 (Approved Lists 1980) emend. Gupta et al. 2013 * authority | spirochetes * blast name')
# (137, 'Spirochaetaceae * scientific name | Spirochaetaceae Schwellengrebel 1907 (Approved Lists 1980) emend. Gupta et al. 2013 * authority | Spirochaetaceae Swellengrebel 1907 * authority | Spirochaetaceae Swellengrebel 1907 (Approved Lists 1980) emend. Abt et al. 2012 * authority | Treponemataceae * in-part | Treponemataceae Robinson 1948 (Approved Lists 1980) * authority')
# (138, 'Borrelia * scientific name | Borrelia Swellengrebel 1907 (Approved Lists 1980) emend. Adeolu and Gupta 2014 * authority | Relapsing Fever Borrelia * synonym')
# (139, 'Borrelia burdorferi * synonym | Borrelia burgdorferi * synonym | Borrelia burgdorferi Johnson et al. 1984 emend. Baranton et al. 1992 * authority | Borrelia burgdorferi sensu stricto * synonym | Borrelia burgdorffragment * synonym | Borreliella burgdorferi * scientific name | Borreliella burgdorferi (Johnson et al. 1984) Adeolu and Gupta 2015 * authority | Lyme disease spirochete * genbank common name')
# (140, '"Spirochaeta hermsi" (sic) Davis 1942 * authority | Borrelia hermsii * scientific name | Borrelia hermsii (Davis 1942) Steinhaus 1946 * authority | Spirochaeta hermsi * synonym')
# (141, '"Spirochaeta parkeri" Davis 1942 * authority | Borrelia parkeri * scientific name | Borrelia parkeri (Davis 1942) Steinhaus 1946 * authority | Spirochaeta parkeri * synonym')
# (142, '"Spirochaeta turicatae" Brumpt 1933 * authority | Borrelia turicatae * scientific name | Borrelia turicatae (Brumpt 1933) Steinhaus 1946 * authority | Spirochaeta turicatae * synonym')
# (143, '"Spirochaeta anserina" Sakharoff 1891 * authority | "Spirochaete gallinarum" (sic) Stephens and Christophers 1904 * authority | "Spiroschaudinnia anserina" (Sakharoff 1891) Sambon 1907 * authority | Borrelia anserina * scientific name | Borrelia anserina (Sakharoff 1891) Bergey et al. 1925 * authority | Spirochaeta anserina * synonym | Spirochaete gallinarum * synonym | Spiroschaudinnia anserina * synonym')
# (144, 'Borrelia coriaceae * scientific name | Borrelia coriaceae Johnson et al. 1987 * authority')
# (145, 'Borrelia sp. * scientific name')
# (146, '"Ehrenbergia" Gieszczykiewiez 1939 * authority | "Spirochaete" Cohn 1872 (orthographic variant of Spirochaeta) * authority | "Spirochoeta" Dujardin 1841 (orthographic variant of Spirochaeta) * authority | Ehrenbergia * synonym | Spirochaeta * scientific name | Spirochaeta Ehrenberg 1835 (Approved Lists 1980) emend. Abt et al. 2012 * authority | Spirochaeta Ehrenberg 1835 (Approved Lists 1980) emend. Miyazaki et al. 2014 * authority | Spirochaeta Ehrenberg 1835 (Approved Lists 1980) emend. Pikuta et al. 2009 * authority | Spirochaeta Ehrenberg 1835 (Approved Lists 1980) emend. Shivani et al. 2015 * authority | Spirochaete * synonym | Spirochoeta * synonym')
# (147, '"Spirochaeta aurantia" Vinzent 1926 * authority | Spirochaeta aurantia * scientific name | Spirochaeta aurantia (ex Vinzent 1926) Canale-Parola 1980 * authority')
# (148, 'Sediminispirochaeta bajacaliforniensis * scientific name | Sediminispirochaeta bajacaliforniensis (Fracek and Stolz 2004) Shivani et al. 2016 * authority | Spirochaeta bajacaliforniensis * synonym | Spirochaeta bajacaliforniensis Fracek and Stolz 2004 * authority')
# (149, 'Spirochaeta halophila * scientific name | Spirochaeta halophila Greenberg and Canale-Parola 1977 * authority')
# (150, 'Spirochaeta isovalerica * scientific name | Spirochaeta isovalerica Harwood and Canale-Parola 1983 * authority')
# (151, '"Spirochaeta litoralis" Hespell and Canale-Parola 1970 * authority | Oceanispirochaeta litoralis * scientific name | Oceanispirochaeta litoralis (Canale-Parola 1980) Subhash and Lee 2017 * authority | Spirochaeta litoralis * synonym | Spirochaeta litoralis (ex Hespell and Canale-Parola 1970) Canale-Parola 1980 * authority')
# (152, '"Treponema stenostrepta" (Zuelzer 1912) Abt et al. 2013 * authority | Spirochaeta stenostrepta * synonym | Spirochaeta stenostrepta Zuelzer 1912 * authority | Treponema stenostrepta * synonym | Treponema stenostreptum * scientific name | Treponema stenostreptum corrig. (Zuelzer 1912) Abt et al. 2013 * authority')
# (154, 'Spirochaeta thermophila * scientific name | Spirochaeta thermophila Aksenova et al. 1992 * authority')
# (156, '"Spirochaeta zuelzerae" (Veldkamp 1960) Canale-Parola, Udris and Mandel 1968 * authority | "Treponema zuelzerae" Veldkamp 1960 * authority | Spirochaeta zuelzerae * synonym | Spirochaeta zuelzerae (ex Veldkamp 1960) Canale-Parola 1980 * authority | Treponema zuelzerae * scientific name | Treponema zuelzerae (Canale-Parola 1980) Abt et al. 2013 * authority')
# (157, '"Microspironema" Stiles and Pfender 1905 * authority | "Spironema" Vuillemin 1905 * synonym | Microspironema * synonym | Treponema * scientific name | Treponema Schaudinn 1905 * authority | Treponema Schaudinn 1905 emend Abt et al. 2013 * authority')
# (158, '"Spirillum dentium" (Miller 1889) Sternberg 1892 * authority | "Spirochaeta ambigua" Seguin and Vinzent 1936 * authority | "Spirochaeta comandonii" Seguin and Vinzent 1936 * authority | "Spirochaeta dentium" (Miller 1889) Migula 1895 * authority | "Spirochaeta microdentium" (Noguchi 1912) Heim 1922 * authority | "Spirochaeta orthodonta" Hoffmann 1920 * authority | "Spirochaete denticola" Flugge 1886 * authority | "Spirochaete dentium" Miller 1889 * authority | "Spironema dentium" (Miller 1889) Gross 1912 * authority | "Treponema ambiguum" (Seguin and Vinzent 1936) Prevot 1940 * authority | "Treponema comandonii" (Seguin and Vinzent 1936) Prevot 1940 * authority | "Treponema dentium" (Miller 1889) Dobell 1912 * authority | "Treponema dentium-stenogyratum" Pettit 1928 * authority | "Treponema microdentium" Noguchi 1912 * authority | "Treponema orthodontum" (Hoffmann 1920) Noguchi 1928 * authority | Spirillum dentium * synonym | Spirochaeta ambigua * synonym | Spirochaeta comandonii * synonym | Spirochaeta dentium * synonym | Spirochaeta microdentium * synonym | Spirochaeta orthodonta * synonym | Spirochaete denticola * synonym | Spirochaete dentium * synonym | Spironema dentium * synonym | Treponema ambiguum * synonym | Treponema comandonii * synonym | Treponema denticola * scientific name | Treponema denticola (ex Brumpt 1925) Chan et al. 1993 * authority | Treponema denticola (ex Flugge 1886) Chan et al. 1993 * authority | Treponema dentium * synonym | Treponema dentium-stenogyratum * synonym | Treponema microdentium * synonym | Treponema orthodontum * synonym')
# (159, 'Brachyspira hyodysenteriae * scientific name | Brachyspira hyodysenteriae (Harris et al. 1972) Ochiai et al. 1998 * authority | Serpulina hyodysenteriae * synonym | Serpulina hyodysenteriae (Harris et al. 1972) Stanton 1992 * authority | Treponema hyodysenteriae * synonym | Treponema hyodysenteriae Harris et al. 1972 (Approved Lists 1980) * authority')
# (160, '"Microspironema pallidum" (Schaudinn and Hoffmann 1905) Stiles and Pfender 1905 * authority | "Spirillum pallidum" (Schaudinn and Hoffmann 1905) Mace 1913 * authority | "Spirochaeta pallida" Schaudinn and Hoffmann 1905 * authority | "Spironema pallidum" (Schaudinn and Hoffmann 1905) Vuillemin 1905 * authority | Microspironema pallidum * synonym | Spirillum pallidum * synonym | Spirochaeta pallida * synonym | Spironema pallidum * synonym | Treponema pallidum * scientific name | Treponema pallidum (Schaudinn and Hoffmann 1905) Schaudinn 1905 * authority')
# (161, '"Treponema pallidum subsp. pallidum" (Schaudinn and Hoffmann 1905) Schaudinn 1905 * authority | Treponema pallidum pallidum * equivalent name | Treponema pallidum subsp. pallidum * scientific name | syphilis treponeme * genbank common name')
# (162, '"Treponema phagedenis" (Noguchi 1912) Brumpt * authority | Treponema phagedenis * scientific name')
# (163, 'Treponema bryantii * scientific name | Treponema bryantii Stanton and Canale-Parola 1980 * authority')
# (164, 'Treponema pectinivorum * equivalent name | Treponema pectinovorum * scientific name | Treponema pectinovorum Smibert and Burmeister 1983 * authority')
# (165, 'Treponema saccharophilum * scientific name | Treponema saccharophilum Paster and Canale-Parola 1986 * authority')
# (166, 'Treponema sp. * scientific name')
# (167, 'Treponema succinifaciens * scientific name | Treponema succinifaciens Cwyk and Canale-Parola 1981 * authority')
# (168, '"Treponema pallidum subsp. pertenue" Smibert 1984 * authority | Treponema pallidum pertenue * equivalent name | Treponema pallidum subsp. pertenue * scientific name | Treponema pertenue * synonym | yaws treponeme * genbank common name')
# (170, 'Leptospiraceae * scientific name | Leptospiraceae Hovind-Hougen 1979 (Approved Lists 1980) emend. Levett et al. 2005 * authority | Leptospiraceae Hovind-Houger (sic) 1978 (sic) * authority | Treponemataceae * in-part | Treponemataceae Robinson 1948 (Approved Lists 1980) * authority')
# (171, 'Leptospira * scientific name | Leptospira Noguchi 1917 (Approved Lists 1980) emend. Faine and Stallman 1982 * authority')
# (172, '"Spirochaeta biflexa" Wolbach and Binger 1914 * authority | Leptospira biflexa * scientific name | Leptospira biflexa (Wolbach and Binger 1914) Noguchi 1918 (Approved Lists 1980) emend. Faine and Stallman 1982 * authority | Leptospira sp. 201601958 * includes | Leptospira sp. 201601959 * includes | Leptospira sp. 201601960 * includes | Leptospira sp. 201601961 * includes | Leptospira sp. 201601962 * includes | Spirochaeta biflexa * in-part')
# (173, '"Leptospira icteroides" Noguchi 1919 * authority | "Spirochaeta biflexa" Wolbach and Binger 1914 * authority | "Spirochaeta icterogenes" Uhlenhuth and Fromme 1916 * authority | "Spirochaeta icterohaemorrhagiae" Inada et al. 1916 * authority | "Spirochaeta interrogans" Stimson 1907 * authority | "Spirochaeta nodosa" Hubener and Reiter 1916 * authority | Leptospira icteroides * synonym | Leptospira interrogans * scientific name | Leptospira interrogans (Stimson 1907) Wenyon 1926 (Approved Lists 1980) emend. Faine and Stallman 1982 * authority | Spirochaeta biflexa * in-part | Spirochaeta icterogenes * synonym | Spirochaeta icterohaemorrhagiae * synonym | Spirochaeta interrogans * synonym | Spirochaeta nodosa * synonym')
# (174, 'Leptospira borgpetersenii * scientific name | Leptospira borgpetersenii Yasuda et al. 1987 * authority')
# (176, 'Leptospira hardjo * synonym | Leptospira interrogans serovar Hardjo * scientific name')
# (178, 'Leptospira sp. * scientific name')
# (179, '"Leptospirillum" Markosyan 1972 * authority | Leptospirillum * scientific name | Leptospirillum (ex Markosyan 1972) Hippe 2000 * authority')
# (180, '"Leptospirillum ferrooxidans" Markosyan 1972 * authority | Leptospirillum ferrooxidans * scientific name | Leptospirillum ferrooxidans (ex Markosyan 1972) Hippe 2000 * authority | Leptospirillum sp. DSM 2391 * includes')
# (181, 'Leptospirillum sp. * scientific name')
# (183, '"Leptospira illini" Hanson et al. 1974 * authority | Leptonema illini * scientific name | Leptonema illini Hovind-Hougen 1983 * authority | Leptospira illini * synonym')
# (185, 'Wall less Spirochaeta sp. * synonym | wall-less Spirochaeta sp. * synonym | wall-less spirochete * scientific name')
# (187, 'Aquaspirillum * scientific name | Aquaspirillum Hylemon et al. 1973 * authority')
# (188, 'Aquaspirillum magnetotacticum * synonym | Aquaspirillum magnetotacticum Maratea and Blakemore 1981 * authority | Magnetospirillum magnetotacticum * scientific name | Magnetospirillum magnetotacticum (Maratea and Blakemore 1981) Schleifer et al. 1992 * authority')
# (189, '"Spirillum itersonii" Giesberger 1936 * authority | Aquaspirillum itersonii * synonym | Aquaspirillum itersonii (Giesberger 1936) Hylemon et al. 1973 * authority | Novispirillum itersonii * scientific name | Novispirillum itersonii (Giesberger 1936) Yoon et al. 2007 * authority | Spirillum itersonii * synonym')
# (190, '"Spirillum serpens" (Muller 1786) Winter 1884 * authority | "Vibrio serpens" Muller 1786 * authority | Aquaspirillum bengal * synonym | Aquaspirillum bengal Kumar et al. 1974 (Approved Lists 1980) * authority | Aquaspirillum serpens * scientific name | Aquaspirillum serpens (Muller 1786) Hylemon et al. 1973 (AL 1980) emend. Boivin et al. 1985 * authority | Spirillum serpens * synonym | Vibrio serpens * synonym')
# (191, 'Azospirillum * scientific name | Azospirillum Tarrand et al. 1979 (Approved Lists 1980) emend. Falk et al. 1985 * authority')
# (192, 'Azospirillum brasilense * scientific name | Azospirillum brasilense corrig. Tarrand et al. 1979 * authority | Azospirillum brasiliense * synonym | Roseomonas fauriae * synonym | Roseomonas fauriae Rihs et al. 1998 * authority | Spirillum lipoferum * synonym | bacterium ASAZOES-148 * includes')
# (193, '"Spirillum lipoferum" Beijerinck 1925 * synonym | Azospirillum lipoferum * scientific name | Azospirillum lipoferum (Beijerinck 1925) Tarrand et al. 1979 * authority')
# (194, 'Campylobacter * scientific name | Campylobacter Sebald and Veron 1963 (Approved Lists 1980) emend. Tanner et al. 1981 * authority | Campylobacter Sebald and Veron 1963 (Approved Lists 1980) emend. Vandamme et al. 1991 * authority | Campylobacter Sebald and Veron 1963 (Approved Lists 1980) emend. Vandamme et al. 2010 * authority')
# (195, '"Vibrio coli" Doyle 1948 * authority | Campylobacter coli * scientific name | Campylobacter coli (Doyle 1948) Veron and Chatelain 1973 * authority | Campylobacter hyoilei * genbank synonym | Campylobacter hyoilei Alderton et al. 1995 * authority | Campylobacter sp. OH-18-18281-4B * includes | Campylobacter sp. OH-18-7816 * includes | Vibrio coli * synonym')
# (196, '"Spirillum fetus" Lehmann and Neumann 1927 * authority | "Vibrio fetus" Smith and Taylor 1919 * authority | Campylobacter fetus * scientific name | Campylobacter fetus (Smith and Taylor 1919) Sebald and Veron 1963 * authority | Spirillum fetus * synonym | Vibrio fetus * synonym')
# (197, '"Campylobacter fetus subsp. jejuni" Smibert 1974 * authority | "Vibrio hepaticus" Mathey and Rissberger 1964 * authority | "Vibrio jejuni" Jones et al. 1931 * authority | Campylobacter fetus subsp. jejuni * synonym | Campylobacter jejuni * scientific name | Campylobacter jejuni (Jones et al. 1931) Veron and Chatelain 1973 * authority | Campylobacter sp. AG18-0001 * includes | Campylobacter sp. AG18-0002 * includes | Campylobacter sp. AG18-0003 * includes | Campylobacter sp. AG18-0027 * includes | Campylobacter sp. CFSAN080682 * includes | Campylobacter sp. OH-13-16058 * includes | Campylobacter sp. OH-13-16470-3 * includes | Campylobacter sp. OH-13-28726 * includes | Campylobacter sp. OH-18-10249 * includes | Campylobacter sp. OH-18-14936 * includes | Campylobacter sp. OH-18-15124 * includes | Campylobacter sp. OH-18-15133 * includes | Campylobacter sp. OH-18-15144 * includes | Campylobacter sp. OH-18-15321-1 * includes | Campylobacter sp. OH-18-15321-2 * includes | Campylobacter sp. OH-18-15321-3 * includes | Campylobacter sp. OH-18-15321-4 * includes | Campylobacter sp. OH-18-18281-4A * includes | Campylobacter sp. OH-18-19951-2 * includes | Campylobacter sp. OH-18-8054 * includes | Vibrio hepaticus * synonym | Vibrio jejuni * synonym')
# (198, 'Campylobacter hyointestinalis * scientific name | Campylobacter hyointestinalis Gebhart et al. 1985 emend. On et al. 1995 * authority')
# (199, 'Campylobacter concisus * scientific name | Campylobacter concisus Tanner et al. 1981 * authority')
# (200, 'Campylobacter curvus * scientific name | Campylobacter curvus (Tanner et al. 1984) Vandamme et al. 1991 * authority | Wolinella curva * synonym | Wolinella curva Tanner et al. 1984 * authority')
# (201, 'Campylobacter lari * scientific name | Campylobacter lari corrig. Benjamin et al. 1984 emend. Debruyne et al. 2009 * authority | Campylobacter laridis * synonym')
# (202, 'Campylobacter mucosalis * scientific name | Campylobacter mucosalis (Lawson et al. 1981) Roop et al. 1985 * authority | Campylobacter sputorum mucosalis * synonym | Campylobacter sputorum subsp. mucosalis * synonym | Campylobacter sputorum subsp. mucosalis (ex Lawson and Rowland 1974) Lawson et al. 1981 * authority')
# (203, 'Campylobacter rectus * scientific name | Campylobacter rectus (Tanner et al. 1981) Vandamme et al. 1991 * authority | Wolinella recta * synonym | Wolinella recta Tanner et al. 1981 * authority')
# (204, 'Campylobacter showae * scientific name | Campylobacter showae Etoh et al. 1993 * authority')
# (205, 'Campylobacter sp. * scientific name')
# (206, '"Vibrio sputorum" Prevot 1940 * authority | Campylobacter sputorum * scientific name | Campylobacter sputorum (Prevot 1940) Veron and Chatelain 1973 (Approved Lists 1980) emend. On et al. 1998 * authority | Campylobacter sputorum (Prevot 1940) Veron and Chatelain 1973 (Aproved Lists 1980) emend. Roop et al. 1986 * authority | Vibrio sputorum * synonym')
# (207, 'Campylobacter jejuni-like bacterium * scientific name')
# (209, 'Gastrospirillum * includes | Helicobacter * scientific name | Helicobacter Goodwin et al. 1989 emend. Vandamme et al. 1991 * authority')
# (210, 'Campylobacter pylori * synonym | Campylobacter pylori Marshall et al. 1985 corrig. Marshall and Goodwin 1987 * authority | Campylobacter pylori corrig. Marshall et al. 1985 emend. Fox et al. 1988 * authority | Campylobacter pylori corrig. Marshall et al. 1985 emend. Fox et al. 1989 * authority | Campylobacter pylori subsp. pylori * synonym | Campylobacter pylori subsp. pylori Marshall et al. 1985 * authority | Campylobacter pyloridis * synonym | Campylobacter pyloridis Marshall et al.1985 * authority | Helicobacter nemestrinae * synonym | Helicobacter nemestrinae Bronsdon et al. 1991 * authority | Helicobacter pylori * scientific name | Helicobacter pylori (Marshall et al. 1985) Goodwin et al. 1989 * authority')
# (211, 'Campylobacter-like organism 3 * synonym | Helicobacter CLO3 * synonym | Helicobacter sp. (strain CLO3) * synonym | Helicobacter sp. CLO-3 * scientific name | Helicobacter sp. CLO3 * synonym')
# (212, 'Helicobacter acinonychis * scientific name | Helicobacter acinonychis corrig. Eaton et al. 1993 * authority | Helicobacter acinonyx * synonym')
# (213, '"Helicobacter westmeadii" Trivett-Moore et al. 1997 * authority | Campylobacter cinaedi * synonym | Campylobacter cinaedi Totten et al. 1988 * authority | Helicobacter cinaedi * scientific name | Helicobacter cinaedi (Totten et al. 1988) Vandamme et al. 1991 * authority | Helicobacter westmeadii * synonym')
# (214, 'Helicobacter felis * scientific name | Helicobacter felis Paster et al. 1991 * authority')
# (215, 'Campylobacter fennelliae * synonym | Campylobacter fennelliae Totten et al. 1988 * authority | Helicobacter fennelliae * scientific name | Helicobacter fennelliae (Totten et al. 1988) Vandamme et al. 1991 * authority')
# (216, 'Helicobacter muridarum * scientific name | Helicobacter muridarum Lee et al. 1992 * authority')
# (217, 'Campylobacter mustelae * synonym | Campylobacter mustelae (Fox et al. 1988) Fox et al. 1989 * authority | Campylobacter pylori mustelae * synonym | Campylobacter pylori subsp. mustelae * synonym | Campylobacter pylori subsp. mustelae Fox et al. 1988 * authority | Helicobacter mustelae * scientific name | Helicobacter mustelae (Fox et al. 1988) Goodwin et al. 1989 * authority')
# (218, 'Helicobacter sp. * scientific name')
# (222, 'Achromobacter * scientific name | Achromobacter Yabuuchi and Yano 1981 emend. Yabuuchi et al. 1998 * authority')
# (223, '"Achromobacter cycloclastes" (Gray and Thornton) Bergey et al. * authority | Achromobacter cycloclastes * scientific name')
# (224, '"Achromobacter lyticus" Isono et al. 1972 * authority | Achromobacter lyticus * scientific name')
# (226, 'Alteromonas * scientific name | Alteromonas Baumann et al. 1972 (Approved Lists 1980) emend. Gauthier et al. 1995 * authority | Alteromonas Baumann et al. 1972 (Approved Lists 1980) emend. Novick and Tyler 1985 * authority | Alteromonas Baumann et al. 1972 (Approved Lists 1980) emend. Van Trappen et al. 2004 * authority')
# (227, 'Alteromonas carrageenovora * synonym | Pseudoalteromonas carrageenovora * scientific name | Pseudoalteromonas carrageenovora (Akagawa-Matsushita et al. 1992) Gauthier et al. 1995 * authority')
# (228, '"Alteromonas marinopraesens" (ZoBell and Upham 1944) Baumann et al. 1972 * authority | "Vibrio haloplanktis" ZoBell and Upham 1944 * authority | "Vibrio marinopraesens" ZoBell and Upham 1944 * authority | Alteromonas haloplanktis * synonym | Alteromonas haloplanktis (ZoBell and Upham 1944) Reichelt and Baumann 1973 (Approved Lists 1980) * authority | Alteromonas marinopraesens * synonym | Moraxella sp. TAC 125 * includes | Pseudoalteromonas haloplanktis * scientific name | Pseudoalteromonas haloplanktis (ZoBell and Upham 1944) Gauthier et al. 1995 * authority | Psychrophilic bacterium (strain TAE 79) * includes | Vibrio haloplanktis * synonym | Vibrio marinopraesens * synonym | psychrophilic bacterium TAE 79 * includes')
# (232, 'Alteromonas sp. * scientific name')
# (234, 'Brucella * scientific name | Brucella Meyer and Shaw 1920 * authority')
# (235, '"Bacterium abortus" Schmidt in Schmidt and Weis 1901 * authority | Bacterium abortus * synonym | Brucella abortus * scientific name | Brucella abortus (Schmidt 1901) Meyer and Shaw 1920 (Approved Lists 1980) * authority | Brucella melitensis biovar Abortus * genbank synonym | Brucella melitensis bv. Abortus * equivalent name')
# (236, 'Brucella melitensis biovar Ovis * genbank synonym | Brucella melitensis bv. Ovis * equivalent name | Brucella ovis * scientific name | Brucella ovis Buddle 1956 (Approved Lists 1980) * authority')
# (237, 'Flavobacterium * scientific name | Flavobacterium Bergey et al. 1923 (Approved Lists 1980) emend. Bernardet et al. 1996 * authority | Flavobacterium Bergey et al. 1923 (Approved Lists 1980) emend. Dong et al. 2013 * authority | Flavobacterium Bergey et al. 1923 (Approved Lists 1980) emend. Kang et al. 2013 * authority | Flavobacterium Bergey et al. 1923 (Approved Lists 1980) emend. Kuo et al. 2013 * authority')
# (238, 'Chryseobacterium (Flavobacterium) meningosepticum * synonym | Chryseobacterium meningosepticum * synonym | Chryseobacterium meningosepticum (King 1959) Vandamme et al. 1994 * authority | Elizabethkingia meningoseptica * scientific name | Elizabethkingia meningoseptica (King 1959) Kim et al. 2005 emend. Nicholson et al. 2018 * authority | Flavobacterium menginosepticum * synonym | Flavobacterium meningosepticum * synonym | Flavobacterium meningosepticum King 1959 (Approved Lists 1980) * authority')
# (239, 'Flavibacterium sp. * equivalent name | Flavobacterium sp. * scientific name')
# (240, 'Flavibacterium sp. 141-8 * equivalent name | Flavobacterium 141-8 * synonym | Flavobacterium sp. (strain 141-8) * synonym | Flavobacterium sp. 141-8 * scientific name | Flavobacterium sp. strain 141-8 * synonym')
# (241, 'Flavibacterium sp. SC12154 * equivalent name | Flavobacterium SC12154 * synonym | Flavobacterium sp. (strain SC 12,154) * synonym | Flavobacterium sp. SC12154 * scientific name | Flavobacterium sp. strain SC 12154 * synonym')
# (242, 'Flavibacterium sp. U-188 * equivalent name | Flavobacterium U-188 * synonym | Flavobacterium sp. (strain U-188) * synonym | Flavobacterium sp. U-188 * scientific name')
# (244, 'Flavobacterium okeanokoites * synonym | Flavobacterium okeanokoites (IFO 12536) * includes | Flavobacterium okeanokoites IFO12536 * includes | Flavobacterium okeanokoites ZoBell and Upham 1944 (Approved Lists 1980) * authority | Planococcus okeanokoites * synonym | Planococcus okeanokoites (ZoBell and Upham 1944) Nakagawa et al. 1996 * authority | Planococcus okeanokoites IFO 12536 * includes | Planococcus okeanokoites IFO12536 * includes | Planococcus okeanokoites Nakagawa et al. 1996 (sic) * authority | Planomicrobium okeanokoites * scientific name | Planomicrobium okeanokoites (Nakagawa et al. 1996) Yoon et al. 2001 (sic) * authority | Planomicrobium okeanokoites (ZoBell and Upham 1944) Yoon et al. 2001 * authority | Planomicrobium sp. K3B3a * includes')
# (245, '"Bacillus aquatilis" Frankland and Frankland 1889 * authority | "Bacterium aquatilis" (sic) (Frankland and Frankland 1889) Chester 1897 * authority | "Chromobacterium aquatilis" (sic) (Frankland and Frankland 1889) Topley and Wilson 1929 * authority | "Empedobacter aquatile" (sic) (Frankland and Frankland 1889) Brisou et al. 1960 * authority | "Flavobacterium aquatilis" (sic) (Frankland and Frankland 1889) Bergey et al. 1923 * authority | Bacillus aquatilis * synonym | Bacterium aquatilis * synonym | Chromobacterium aquatilis * synonym | Empedobacter aquatile * synonym | Flavibacterium aquatile * equivalent name | Flavobacterium aquatile * scientific name | Flavobacterium aquatile (Frankland and Frankland 1889) Bergey et al. 1923 (Approved Lists 1980) emend. Bernardet et al. 1996 * authority | Flavobacterium aquatile (Frankland and Frankland 1889) Bergey et al. 1923 (Approved Lists 1980) emend. Hahnke et al. 2016 * authority | Flavobacterium aquatile (Frankland and Frankland 1889) Bergey et al. 1923 (Approved Lists 1980) emend. Lee et al. 2012 * authority | Flavobacterium aquatile (Frankland and Frankland 1889) Bergey et al. 1923 (Approved Lists 1980) emend. Sheu et al. 2013 * authority | Flavobacterium aquatilis * synonym')
# (246, 'Chryseobacterium balustinum * scientific name | Chryseobacterium balustinum (Harrison 1929) Vandamme et al. 1994 * authority | Flavobacterium balustinum * synonym | Flavobacterium balustinum Harrison 1929 (Approved Lists 1980) * authority')
# (247, '"Bacillus brevis" Lustig 1890 * synonym | "Bacillus canalis parvus" Eisenberg 1891 * authority | "Bacillus canicolis brevis" Cornil and Babes 1890 * authority | "Bacterium breve" (Lustig 1890) Chester 1901 * authority | "Bacterium canale" Mez 1898 * authority | "Bacterium canalis parvus" (sic) (Eisenberg 1891) Chester 1897 * authority | "Empedobacter breve" (sic) (Lustig 1890) Prevot 1961 * authority | "Flavobacterium brevis" (sic) (Lustig 1890) Bergey et al. 1923 * synonym | "Pseudobacterium brevis" (sic) (Lustig 1890) Krasil\'nikov 1949 * authority | Bacillus canalis parvus * synonym | Bacillus canicolis brevis * synonym | Bacterium breve * synonym | Bacterium canale * synonym | Bacterium canalis parvus * synonym | Empedobacter breve * synonym | Empedobacter brevis * scientific name | Empedobacter brevis (Holmes and Owen 1982) Vandamme et al. 1994 emend. Hahnke et al. 2016 * authority | Empedobacter brevis (Holmes and Owen 1982) Vandamme et al. 1994 emend. Zhang et al. 2014 * authority | Flavobacterium breve * synonym | Flavobacterium breve (ex Lustig 1890) Holmes and Owen 1982 * authority | Pseudobacterium brevis * synonym')
# (249, '"Empedobacter ferrugineum" (sic) (Sickles and Shaw 1934) Prevot 1961 * authority | "Pseudobacterium ferrugineum" (Sickles and Shaw 1934) Krasil\'nikov 1949 * authority | Empedobacter ferrugineum * synonym | Flavibacterium ferrugineum * synonym | Flavobacterium ferrugineum * synonym | Flavobacterium ferrugineum Sickles and Shaw 1934 (Approved Lists 1980) * authority | Imcbia ferrugineum * synonym | Pseudobacterium ferrugineum * synonym | Terrimonas ferruginea * scientific name | Terrimonas ferruginea (Sickles and Shaw 1934) Xie and Yokota 2006 emend. Jin et al. 2013 * authority')
# (250, 'Chryseobacterium gleum * scientific name | Chryseobacterium gleum (Holmes et al. 1984) Vandamme et al. 1994 emend. Hahnke et al. 2016 * authority | Chryseobacterium gleum (Holmes et al. 1984) Vandamme et al. 1994 emend. Montero-Calasanz et al. 2014 * authority | Chryseobacterium gleum (Holmes et al. 1984) Vandamme et al. 1994 emend. Nguyen et al. 2013 * authority | Chryseobacterium sp. SKB * includes | Flavobacterium gleum * synonym | Flavobacterium gleum Holmes et al. 1984 * authority')
# (251, 'Flavobacterium gondwanense * synonym | Flavobacterium gondwanense Dobson et al. 1993 * authority | Psychroflexus gondwanensis * scientific name | Psychroflexus gondwanensis corrig. (Dobson et al. 1993) Bowman et al. 1999 emend. Hahnke et al. 2016 * authority')
# (252, 'Flavobacterium halmephilium * synonym | Flavobacterium halmephilum * synonym | Flavobacterium halmophilum * synonym | Flavobacterium halmophilum corrig. Elazari-Volcani 1940 (Approved Lists 1980) * authority | Halomonas halmophila * scientific name | Halomonas halmophila (Elazari-Volcani 1940) Franzmann et al. 1989 emend. Dobson et al. 1990 * authority')
# (253, 'Chryseobacterium indologenes * scientific name | Chryseobacterium indologenes (Yabuuchi et al. 1983) Vandamme et al. 1994 emend. Montero-Calasanz et al. 2013 * authority | Flavobacterium indologenes * synonym | Flavobacterium indologenes Yabuuchi et al. 1983 * authority')
# ...
# (2425, '"Teredinobacter" Waterbury et al. 1989 * synonym | Teredinibacter * scientific name | Teredinibacter Distel et al. 2002 * authority')
# (2426, '"Teredinobacter turnerae" Waterbury et al. 1989 * synonym | Teredinibacter sp. 991H.S.0a.06 * includes | Teredinibacter turnerae * scientific name | Teredinibacter turnerae Distel et al. 2002 * authority')
# (2428, 'TOL plasmid * scientific name')
# (2429, 'Solemya reidi gill symbiont * scientific name | Solemya reidi symbiont * synonym')
# (2433, 'Roseobacter * scientific name | Roseobacter Shiba 1991 emend. Martens et al. 2006 * authority')
# (2434, 'Erythrobacter sp. (strain OCh 114) * includes | Roseobacter denitrificans * scientific name | Roseobacter denitrificans Shiba 1991 * authority')
# (2436, 'Plasmid CloDF13 * scientific name')
# (2437, 'Plasmid ColA-CA31 * scientific name')
# (2438, 'Plasmid ColA * scientific name')
# (2439, 'Plasmid ColB2 * scientific name')
# (2440, 'Plasmid ColB4 * scientific name')
# (2441, 'Plasmid ColBM-Cl139 * scientific name')
# (2442, 'Plasmid ColD * scientific name')
# (2443, 'Plasmid ColE1 * scientific name | Plasmid Colicin E1 * synonym')
# (2446, 'Plasmid ColE2 * scientific name')
# (2447, 'Plasmid ColE3-CA38 * scientific name')
# (2448, 'Plasmid ColE5-099 * scientific name')
# (2449, 'Plasmid ColE6-CT14 * scientific name')
# (2450, 'Plasmid ColE7 * scientific name')
# (2451, 'Plasmid ColE8 * scientific name')
# (2452, 'Plasmid ColE9 * scientific name')
# (2453, 'Plasmid ColIa * scientific name')
# (2454, 'Plasmid ColIb-P9 * scientific name')
# (2455, 'Plasmid ColIb * scientific name')
# (2456, 'Plasmid ColK * scientific name')
# (2457, 'Plasmid ColV-K30 * scientific name')
# (2458, 'Plasmid ColV2-K94 * scientific name')
# (2459, 'Plasmid ColV3-K30 * scientific name')
# (2460, 'Plasmid ColVBtrp * scientific name')
# (2461, 'Plasmid ColV * scientific name')
# (2462, 'Plasmid ENTR * scientific name')
# (2463, 'Plasmid ENT * scientific name')
# (2464, 'Plasmid EWD 299 * scientific name')
# (2465, 'Plasmid F * scientific name')
# (2466, 'Plasmid NAH7 * scientific name')
# (2467, 'Plasmid NR1 * scientific name')
# (2468, 'Plasmid NR79 * scientific name')
# (2469, 'Plasmid NTP16 * scientific name')
# (2470, 'Plasmid P15a * scientific name')
# (2471, 'Plasmid P1 * scientific name')
# (2472, 'Plasmid P307 * scientific name')
# (2473, 'Plasmid P6 * scientific name')
# (2474, 'Plasmid PDS075 * scientific name')
# (2476, 'Plasmid R1-19 * scientific name')
# (2477, 'Plasmid R1033 * scientific name')
# (2478, 'Plasmid R1162 * scientific name')
# (2479, 'Plasmid R124 * scientific name')
# (2480, 'Plasmid R144 * scientific name')
# (2481, 'Plasmid R1767 * scientific name')
# (2482, 'Plasmid R1 * scientific name')
# (2483, 'Plasmid R26 * scientific name')
# (2484, 'Plasmid R27 * scientific name')
# (2485, 'Plasmid R386 * scientific name')
# (2486, 'Plasmid R387 * scientific name')
# (2487, 'Plasmid R401 * scientific name')
# (2488, 'Plasmid R46 * scientific name')
# (2489, 'Plasmid R483 * scientific name')
# (2490, 'Plasmid R485 * scientific name')
# (2491, 'Plasmid R538 * scientific name')
# (2492, 'Plasmid R64 * scientific name')
# (2493, 'Plasmid R65 * scientific name')
# (2494, 'Plasmid R67 * scientific name')
# (2495, 'Plasmid R6K * scientific name')
# (2496, 'Plasmid R751 * scientific name')
# (2497, 'Plasmid R773 * scientific name')
# (2498, 'Plasmid R974 * scientific name')
# (2499, 'Plasmid RGN238 * scientific name')
# (2500, 'Plasmid RI13 * scientific name')
# (2501, 'Plasmid RK2Te-r * scientific name')
# (2502, 'Plasmid RK2 * scientific name')
# (2503, 'Plasmid RP4 * scientific name')
# (2504, 'IncQ plasmid RSF1010 * synonym | Plasmid RSF1010 * scientific name | RSF1010 * synonym')
# (2505, 'Plasmid RSF1030 * scientific name')
# (2506, 'Plasmid Ri * scientific name')
# (2507, 'Plasmid Rts1 * scientific name')
# (2508, 'Plasmid R * scientific name')
# (2509, 'Plasmid SCP1 * scientific name')
# (2510, 'Plasmid SLP1 * scientific name')
# (2511, 'Plasmid SYM * scientific name')
# (2512, 'Plasmid Ti * scientific name')
# (2513, 'Plasmid incB * scientific name')
# (2514, 'Plasmid incI-1 * scientific name')
# (2515, 'Plasmid incI-gamma * scientific name')
# (2516, 'Plasmid p42d * scientific name')
# (2517, 'Plasmid pAA3.7X * synonym | Sequencing vector pAA3.7X * scientific name')
# (2518, 'Plasmid pAC27 * scientific name')
# (2520, 'Plasmid pAD1 * scientific name')
# (2522, 'Plasmid pAL5000 * scientific name')
# (2523, 'Plasmid pAM-beta-1 * scientific name')
# (2524, 'Plasmid pAM77 * scientific name')
# (2525, 'Plasmid pAZ1 * scientific name')
# (2526, 'Plasmid pBAA1 * scientific name')
# (2527, 'Plasmid pBC16 * scientific name')
# (2528, 'Plasmid pBC1 * scientific name')
# (2530, 'Plasmid pBP60-1 * scientific name')
# (2531, 'Plasmid pBS2 * scientific name')
# (2532, 'Plasmid pBWH77 * scientific name')
# (2534, 'Plasmid pC194 * scientific name')
# (2535, 'Plasmid pC30il * scientific name')
# (2536, 'Plasmid pCD1 * scientific name')
# (2538, 'Plasmid pCHL1 * scientific name')
# (2540, 'Plasmid pCMS1 * scientific name')
# (2541, 'Plasmid pCN2 * scientific name')
# (2542, 'Plasmid pCN3 * scientific name')
# (2543, 'Plasmid pCU1 * scientific name')
# (2544, 'Plasmid pColBM-C1139 * scientific name')
# (2546, 'Plasmid pDK1 * scientific name')
# (2547, 'Plasmid pDU1358 * scientific name')
# (2548, 'Plasmid pDU1 * scientific name')
# (2549, 'Plasmid pE194 * scientific name')
# (2550, 'Plasmid pEA3 * scientific name')
# (2551, 'Plasmid pED208 * scientific name')
# (2552, 'Plasmid pEP2 * scientific name')
# (2553, 'Plasmid pEST1226 * scientific name')
# (2554, 'Plasmid pEX102 * scientific name')
# (2555, 'Plasmid pF166 * scientific name')
# (2556, 'Plasmid pFA3 * scientific name')
# (2557, 'Plasmid pGS05 * scientific name')
# (2558, 'Plasmid pHG1 * scientific name')
# (2560, 'Plasmid pHH502 * scientific name')
# (2561, 'Plasmid pHH507 * scientific name')
# (2562, 'Plasmid pHV2 * scientific name')
# (2564, 'Plasmid pI258 * scientific name')
# (2565, 'Plasmid pIB485 * scientific name')
# (2566, 'Plasmid pIE545 * scientific name')
# (2567, 'Plasmid pIJ101 * scientific name')
# (2568, 'Plasmid pIM13 * scientific name')
# (2570, 'Plasmid pIP1433 * scientific name')
# (2571, 'Plasmid pIP1527 * scientific name')
# (2573, 'Plasmid pIP404 * scientific name')
# (2574, 'Plasmid pIP501 * scientific name')
# (2575, 'Plasmid pIP630 * scientific name')
# (2576, 'Plasmid pIP816 * scientific name')
# (2577, 'Plasmid pJD1 * scientific name')
# (2578, 'Plasmid pJHC-MW1 * scientific name')
# (2580, 'Plasmid pJP4 * scientific name')
# (2581, 'Plasmid pJR225 * scientific name')
# (2582, 'Plasmid pJS37 * scientific name')
# (2584, 'Plasmid pKLH104 * scientific name')
# (2585, 'Plasmid pKLH1 * scientific name')
# (2586, 'Plasmid pKLH202 * scientific name')
# (2588, 'Plasmid pKM101 * scientific name')
# (2589, 'Plasmid pKY1 * scientific name')
# (2590, 'Plasmid pKYM * scientific name')
# (2591, 'Plasmid pLAB1000 * scientific name')
# (2592, 'Plasmid pLB1 * scientific name')
# (2593, 'Plasmid pLP1 * scientific name')
# (2594, 'Plasmid pLS11 * scientific name')
# (2595, 'Plasmid pLS1 * scientific name')
# (2596, 'Plasmid pME2001 * scientific name')
# (2597, 'Plasmid pMEA100 * scientific name')
# (2598, 'Plasmid pMK157 * scientific name')
# (2599, 'Plasmid pMM110 * scientific name')
# (2600, 'Plasmid pMM237 * scientific name')
# (2601, 'Plasmid pMM25-3 * synonym | Recombinant plasmid pMM25-3 * scientific name')
# (2602, 'Plasmid pMM5-3 * synonym | Recombinant plasmid pMM5-3 * scientific name')
# (2603, 'Plasmid pMM5-5 * synonym | Recombinant plasmid pMM5-5 * scientific name')
# (2604, 'Plasmid pMON234 * scientific name')
# (2605, 'Plasmid pMU707 * scientific name')
# (2606, 'Plasmid pMV158 * scientific name')
# (2607, 'Plasmid pMYSH6000 * scientific name')
# (2608, 'Plasmid pNE131 * scientific name')
# (2609, 'Plasmid pNG2 * scientific name')
# (2611, 'Plasmid pNRC100 * scientific name')
# (2612, 'Plasmid pNS1981 * scientific name')
# (2613, 'Plasmid pNS1 * scientific name')
# (2616, 'Plasmid pRA1 * scientific name')
# (2618, 'Plasmid pRE-I * scientific name')
# (2619, 'Plasmid pRJF1 * scientific name')
# (2620, 'Plasmid pSA209 * scientific name')
# (2621, 'Plasmid pSA2100 * scientific name')
# (2622, 'Plasmid pSAM2 * scientific name')
# (2623, 'Plasmid pSB24.2 * scientific name')
# (2624, 'Plasmid pSBK203 * scientific name')
# (2625, 'Plasmid pSC101 * scientific name')
# (2626, 'Plasmid pSE211 * scientific name')
# (2627, 'Plasmid pSG1 * scientific name')
# (2628, 'Plasmid pSK11L * scientific name')
# (2629, 'Plasmid pSL1 * scientific name')
# (2630, 'Plasmid pSL2 * scientific name')
# (2631, 'Plasmid pSLP124 * scientific name')
# (2632, 'Plasmid pSM32 * scientific name')
# (2633, 'Plasmid pSMB74 * scientific name')
# (2636, 'Plasmid pSX267 * scientific name')
# (2637, 'Plasmid pSa * scientific name')
# (2638, 'Plasmid pT181 * scientific name')
# (2639, 'Plasmid pT48 * scientific name')
# (2641, 'Plasmid pTB913 * scientific name')
# (2642, 'Plasmid pTD1 * scientific name')
# (2643, 'Plasmid pTF-FC2 * scientific name')
# (2645, 'Plasmid pTiA6 * scientific name')
# (2646, 'Plasmid pTiAB3 * scientific name')
# (2647, 'Plasmid pTiAch5 * scientific name')
# (2648, 'Plasmid pTiAg162 * scientific name')
# (2649, 'Plasmid pTiAg57 * scientific name')
# (2650, 'Plasmid pTiB6S3 * scientific name')
# (2651, 'Plasmid pTiC58 * scientific name')
# (2652, 'Plasmid pTiS4 * scientific name')
# (2653, 'Plasmid pUB110cop1 * scientific name')
# (2655, 'Plasmid pUB110 * scientific name')
# (2656, 'Plasmid pUH1 * scientific name')
# (2657, 'Plasmid pUR400 * scientific name')
# (2658, 'Plasmid pVA380-1 * scientific name')
# (2659, 'Plasmid pVI150 * scientific name')
# (2660, 'Plasmid pWM5 * scientific name')
# (2661, 'Plasmid pWR100 * scientific name')
# (2662, 'Plasmid pWR60 * scientific name')
# (2663, 'Plasmid pWW0 * scientific name')
# (2664, 'Plasmid pWW53 * scientific name')
# (2665, 'Plasmid pYV03 * scientific name')
# (2666, 'Plasmid pYVe439-80 * scientific name')
# (2670, 'Plasmid RP1 * scientific name | RP1 * synonym')
# (2671, 'Integron * synonym | integrons * scientific name')
# (2673, 'Insertion * synonym | insertion sequences * scientific name')
# (2678, 'Insertion sequence IS2 * scientific name')
# (2681, 'Insertion sequence IS407 * scientific name')
# (2684, 'Insertion sequence IS4 * scientific name')
# (2693, 'Incompatibility symbiont of Nasonia vitripennis * scientific name')
# (2694, 'Incompatibility symbiont of Nasonia longicornis * scientific name')
# (2695, 'Incompatibility symbiont of Nasonia giraulti * scientific name')
# (2697, 'Heliobacterium * scientific name | Heliobacterium Gest and Favinger 1985 * authority')
# (2698, 'Heliobacterium chlorum * scientific name | Heliobacterium chlorum Gest and Favinger 1985 * authority')
# (2699, 'Heliobacterium gestii * scientific name | Heliobacterium gestii Ormerod et al. 1996 * authority')
# (2701, 'Gardnerella * scientific name | Gardnerella Greenwood and Pickett 1980 * authority')
# (2702, '"Corynebacterium vaginale" Zinnemann and Turner 1963 * authority | "Haemophilus hemolyticus vaginalis" Lutz et al. 1956 * authority | Corynebacterium vaginale * synonym | Gardnerella vaginalis * scientific name | Gardnerella vaginalis (Gardner and Dukes 1955) Greenwood and Pickett 1980 * authority | Haemophilus hemolyticus vaginalis * synonym | Haemophilus vaginalis * synonym | Haemophilus vaginalis Gardner and Dukes 1955 (Approved Lists 1980) * authority')
# (2704, 'Thermoanaerobacter acetoethylicus * scientific name | Thermoanaerobacter acetoethylicus (Ben-Bassat and Zeikus 1983) Rainey and Stackebrandt 1993 * authority | Thermobacteroides acetoethylicus * synonym | Thermobacteroides acetoethylicus Ben-Bassat and Zeikus 1983 * authority')
# (2706, 'Citrus * scientific name | Citrus L., 1753 * authority | Eremocitrus * includes | Eremocitrus Swingle * authority | Fortunella * includes | Fortunella Swingle * authority | Microcitrus * includes | Microcitrus Swingle * authority')
# (2707, 'Citrus disease bacterium * synonym | Citrus greening disease-associated bacterium * scientific name | Citrus greening disease-associated bacterium-like organism * synonym | bacterium-like organism * synonym')
# (2708, 'Citrus limon * scientific name | Citrus limon (L.) Burm.f. * authority | Citrus limonum * synonym | Citrus limonum Risso * authority | Citrus x limon * synonym | lemon * common name')
# (2709, 'Citrus cavaleriei * scientific name | Citrus cavaleriei H.Lev. ex Cavalerie, 1911 * authority | Citrus ichangensis * synonym | Citrus ichangensis Swingle, 1913 * authority | Ichang papeda * common name')
# (2711, 'Citrus sinensis * scientific name | Citrus sinensis (L.) Osbeck * authority | Citrus x sinensis * synonym | Valencia orange * common name | apfelsine * common name | naranja * common name | navel orange * common name | sweet orange * genbank common name')
# (2713, 'Aquifex * scientific name | Aquifex Huber et al. 1992 * authority')
# (2714, 'Aquifex pyrophilus * scientific name | Aquifex pyrophilus Huber et al. 1992 * authority')
# (2717, 'Cardiobacterium * scientific name | Cardiobacterium Slotnick and Dougherty 1964 * authority')
# (2718, 'Cardiobacterium hominis * scientific name | Cardiobacterium hominis Slotnick and Dougherty 1964 * authority')
# (2722, 'Proteobacterial sp. * synonym | Proteobacterium sp. * synonym | unidentified proteobacterium * scientific name | unknown proteobacterium * synonym')
# (2723, 'Hirschia * scientific name | Hirschia Schlesner et al. 1990 emend. Park and Yoon 2013 * authority')
# (2724, 'Hirschia baltica * scientific name | Hirschia baltica Schlesner et al. 1990 * authority')
# (2725, 'Unknown prokaryotic organism * synonym | unidentified prokaryotic organism * scientific name')
# (2728, '"Candidatus Legionella jeonii" Park et al. 2004 * authority | Amoeba proteus symbiotic bacterium * synonym | Candidatus Legionella jeonii * scientific name | Legionella jeonii * equivalent name | X-bacterium * synonym')
# (2733, 'Symbiobacterium * scientific name | Symbiobacterium Ohno et al. 2000 emend. Shiratori-Takano et al. 2014 * authority')
# (2734, 'Symbiobacteriaceae bacterium G2 * includes | Symbiobacterium sp. No. 67 * includes | Symbiobacterium sp. YK67 * includes | Symbiobacterium thermophilum * scientific name | Symbiobacterium thermophilum Ohno et al. 2000 * authority')
# (2735, 'Verrucomicrobium * scientific name | Verrucomicrobium Schlesner 1988 * authority | Verrucosimicrobium * synonym')
# (2736, 'Verrucomicrobium spinosum * scientific name | Verrucomicrobium spinosum Schlesner 1988 * authority')
# (2737, 'Vagococcus * scientific name | Vagococcus Collins et al. 1990 * authority')
# (2738, 'Vagococcus fluvialis * scientific name | Vagococcus fluvialis Collins et al. 1990 * authority')
# (2739, 'Vagococcus salmoninarum * scientific name | Vagococcus salmoninarum Wallbanks et al. 1990 * authority')
# (2740, 'Peptococcus * scientific name | Peptococcus Kluyver and van Niel 1936 (Approved Lists 1980) emend. Shkoporov et al. 2016 * authority')
# (2741, '"Micrococcus niger" Hall 1930 * authority | Micrococcus niger * synonym | Peptococcus niger * scientific name | Peptococcus niger (Hall 1930) Kluyver and van Niel 1936 * authority')
# (2742, 'Marinobacter * scientific name | Marinobacter Gauthier et al. 1992 * authority')
# (2743, 'Marinobacter aquaeolei * synonym | Marinobacter aquaeolei Nguyen et al. 1999 * authority | Marinobacter hydrocarbonoclasticus * scientific name | Marinobacter hydrocarbonoclasticus Gauthier et al. 1992 * authority | Pseudomonas nautica * synonym | Pseudomonas nautica Bauman et al. 1972 (Approved Lists 1980) * authority')
# (2745, 'Deleya * synonym | Deleya Baumann et al. 1983 emend. Akagawa and Yamasato 1989 * authority | Halomonas * scientific name | Halomonas Vreeland et al. 1980 emend. Dobson and Franzmann 1996 * authority | Volcaniella * includes | Volcaniella Quesada et al. 1990 * authority')
# (2746, 'Halomonas elongata * scientific name | Halomonas elongata Vreeland et al. 1980 * authority')
# (2747, 'Carnibacterium * equivalent name | Carnobacterium * scientific name | Carnobacterium Collins et al. 1987 * authority')
# (2748, 'Carnibacterium divergens * equivalent name | Carnobacterium divergens * scientific name | Carnobacterium divergens (Holzapfel and Gerber 1984) Collins et al. 1987 * authority')
